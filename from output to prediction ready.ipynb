# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# 01 - Creating the features.ipynb
# 01--1-Copy1.2 - Creating the features bike lag +4.ipynb
# 01--1.2 - Creating the features bike lag +4.ipynb
# 01-.2 - Creating the features bike lag +3.ipynb
# 01.2 - Creating the features bike lag +2.ipynb
# 01.2 - Creating the features.ipynb
# 02 - EDA-Copy1.ipynb
# 02 - EDA.ipynb
# 03 - Modelling - ExtraTreesRegressor.ipynb
# 03 - Modelling - LinearRegression (hasn't worked yet, autoregression).ipynb
# 03 - Modelling - LinearRegression.ipynb
# 03 - Modelling - RandomForestClassifier.ipynb
# 03 - Modelling - RandomForestRegressor-plus2-Copy1.ipynb
# 03 - Modelling - RandomForestRegressor-plus2.ipynb
# 03 - Modelling - RandomForestRegressor-plus3.ipynb
# 03 - Modelling - RandomForestRegressor-plus4.ipynb
# 03 - Modelling - RandomForestRegressor.ipynb
# 03 - Modelling - RandomForestRegressor_old.ipynb
# 03 - Modelling - SVM-Copy1.ipynb
# 03 - Modelling - SVM.ipynb
# 03 - Modelling - lot of models.ipynb
# 04 - Live - RandomForestRegressor - Four models in action-Copy1.ipynb
# 04 - Live - RandomForestRegressor - Four models in action-Copy2.ipynb
# 04 - Live - RandomForestRegressor - Four models in action-Copy3.ipynb
# 04 - Live - RandomForestRegressor - Four models in action.ipynb
# 05 - Charts from the data.ipynb
# 05 - Understanding results.ipynb
# 08.18.xlsx
# 176-01-bikelocations.csv
# 176-01-ind_dublinalt.csv.gz
# 176-01-sum_dublinalt.csv
# 2008 machine learning start-Copy1.ipynb
# 2008 machine learning start-Copy2.ipynb
# 2008 machine learning start.ipynb
# 2017-06-25.csv
# 2017-06.csv*
# 2017-06.ipynb
# 2018-06-20.csv
# 2018-06-20.ipynb
# 2018-06-20_features.csv
# 2018-06-20_features2_test.csv
# 2018-06-20_features_test.csv
# 2018-Copy1.ipynb
# 2018.ipynb
# 2018_portobelloroad.csv
# 2018_pulled_features.csv*
# 2018_pulled_features_plusfour.csv*
# EDA-aug02-2018.xlsx
# FINAL PREDICTION - make the features.ipynb
# PORTOBELLO ROAD.csv
# Thursday 2nd August.csv
# Thursday2ndAugust_features.csv
# Thursday2ndAugust_features_clipped.csv
# Untitled.ipynb
# all-station-features-march_on.ipynb
# all-station-features-march_on.py
# all-station-features.ipynb
# aug02-2018.csv
# b4bedtest.csv
# backedup 02 - EDA.ipynb
# basica validation model 1.xlsx
# cp test
# f_features.csv
# features2.csv
# finalized_model_with_pull.sav
# from output to prediction ready.ipynb
# fulldata-spoken.ipynb
# graph-aug02-2018.csv
# ind_dublinalt (2) 2.csv
# ind_dublinalt (2) 3.csv
# ind_dublinalt (2).csv
# ind_dublinalt (2).csv.zip
# knn for neil.ipynb
# machinestarts-2years_all stations.ipynb
# machinestarts.ipynb
# machinestarts2.ipynb
# make_me_work.csv
# mework2.csv
# notebook.tex
# other_output.csv
# output.csv
# ouuu.csv
# paper data/
# pboh-features.ipynb
# pboh.ipynb
# pboh_test 2.csv
# pboh_test.csv
# pivot_mean_hour.csv
# pivot_means.csv
# pivot_means_thursdays.csv
# pivot_means_thursdays_aug.csv
# results.csv
# scattered.ipynb
# station_34.csv
# sum_dublinalt.csv
# testthemodel.csv
# thistookages.csv
# time_series_features.csv
# validateme.csv
# validateme2.csv
# validateme2sss.csv
# validateme3.csv
# validateme4.csv
# validates_all.csv
# validation.csv
# well.csv
# xxx.csv

# %%
names= ['timestamp','station_id','station_name','spaces','bikes']

# %%
#df = pd.read_csv('output.csv',names=names,index_col='timestamp', parse_dates=True)
df = pd.read_csv('output.csv',names=names)

# %%
df = df.sort_values(by=['station_id','timestamp'])

# %%
df['bike_lag'] = df['bikes'].shift().fillna(0).astype(int)

df['bike_lag2'] = df['bikes'].shift(2).fillna(0).astype(int)

df['bike_lag3'] = df['bikes'].shift(3).fillna(0).astype(int)

df['bike_lag4'] = df['bikes'].shift(4).fillna(0).astype(int)

df['bike_pull'] = df['bikes'].shift(-1).fillna(0).astype(int)

df['bike_pull2'] = df['bikes'].shift(-2).fillna(0).astype(int)

df['bike_pull3'] = df['bikes'].shift(-3).fillna(0).astype(int)

df['bike_pull4'] = df['bikes'].shift(-4).fillna(0).astype(int)

df['deposit'] = df['bikes'].diff().fillna(0).astype(int)
df = df.sort_values(by=['timestamp'])

# %%
df.head(2)
# Out:
#                        timestamp  station_id      station_name  spaces  bikes  \
# 274  2018-08-05T01:41:55.313000Z          42  SMITHFIELD NORTH       2     28
# 164  2018-08-05T01:41:55.313000Z          42  SMITHFIELD NORTH       2     28
#
#      bike_lag  bike_lag2  bike_lag3  bike_lag4  bike_pull  bike_pull2  \
# 274        34          7          8          5         25           0
# 164        34          7          8          5         25           0
#
#      bike_pull3  bike_pull4  deposit
# 274           8          26       -6
# 164           8          26       -6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39710 entries, 274 to 39687
# Data columns (total 14 columns):
# timestamp       39710 non-null object
# station_id      39710 non-null int64
# station_name    39710 non-null object
# spaces          39710 non-null int64
# bikes           39710 non-null int64
# bike_lag        39710 non-null int64
# bike_lag2       39710 non-null int64
# bike_lag3       39710 non-null int64
# bike_lag4       39710 non-null int64
# bike_pull       39710 non-null int64
# bike_pull2      39710 non-null int64
# bike_pull3      39710 non-null int64
# bike_pull4      39710 non-null int64
# deposit         39710 non-null int64
# dtypes: int64(12), object(2)
# memory usage: 5.8+ MB

# %%
df = df.set_index('timestamp')

df['hour'] = pd.DatetimeIndex(df.index).hour

df['day_of_week'] = pd.DatetimeIndex(df.index).dayofweek

df['month'] = pd.DatetimeIndex(df.index).month

df['weekend'] = df['day_of_week'] > 4

df['weekend'] = df['weekend'].astype(int)

# %%
df.to_csv('test22.csv')

# %%
df = pd.read_csv('test22.csv')

# %%
df.head()
# Out:
#           timestamp  station_id   station_name  spaces  bikes  bike_lag  \
# 0  2018-08-05 01:41           1  CLARENDON ROW      19     12         0
# 1  2018-08-05 01:41           1  CLARENDON ROW      19     12        12
# 2  2018-08-05 01:41           1  CLARENDON ROW      19     12        12
# 3  2018-08-05 01:47           1  CLARENDON ROW      19     12        12
# 4  2018-08-05 01:47           1  CLARENDON ROW      19     12        12
#
#    bike_lag2  bike_lag3  bike_lag4  bike_pull  bike_pull2  bike_pull3  \
# 0          0          0          0         12          12          12
# 1          0          0          0         12          12          12
# 2         12          0          0         12          12          12
# 3         12         12          0         12          12          12
# 4         12         12         12         12          12          12
#
#    bike_pull4  deposit  hour  day_of_week  month  weekend
# 0          12        0     1            6      8        1
# 1          12        0     1            6      8        1
# 2          12        0     1            6      8        1
# 3          12        0     1            6      8        1
# 4          12        0     1            6      8        1

# %%
df = df.sort_values(by=['timestamp'])
df = df.set_index('timestamp')

# %%
df.head()
# Out:
#                   station_id      station_name  spaces  bikes  bike_lag  \
# timestamp
# 2018-08-05 01:41           1     CLARENDON ROW      19     12         0
# 2018-08-05 01:41          95    ROYAL HOSPITAL       9     31        31
# 2018-08-05 01:41          95    ROYAL HOSPITAL       9     31        31
# 2018-08-05 01:41          41  HARCOURT TERRACE       2     18        18
# 2018-08-05 01:41          41  HARCOURT TERRACE       2     18        20
#
#                   bike_lag2  bike_lag3  bike_lag4  bike_pull  bike_pull2  \
# timestamp
# 2018-08-05 01:41          0          0          0         12          12
# 2018-08-05 01:41         28         28         28         31          31
# 2018-08-05 01:41         31         28         28         31          31
# 2018-08-05 01:41         20         21         21         18          18
# 2018-08-05 01:41         21         21         21         18          18
#
#                   bike_pull3  bike_pull4  deposit  hour  day_of_week  month  \
# timestamp
# 2018-08-05 01:41          12          12        0     1            6      8
# 2018-08-05 01:41          31          31        0     1            6      8
# 2018-08-05 01:41          31          31        0     1            6      8
# 2018-08-05 01:41          18          18        0     1            6      8
# 2018-08-05 01:41          18          18       -2     1            6      8
#
#                   weekend
# timestamp
# 2018-08-05 01:41        1
# 2018-08-05 01:41        1
# 2018-08-05 01:41        1
# 2018-08-05 01:41        1
# 2018-08-05 01:41        1
