# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# 123.csv                     merging.ipynb
# Untitled.ipynb              messing all fileters.ipynb
# alltogether.csv             seasons1to3.csv
# alltogether_outer.csv       simpsons_characters.csv*
# filters_new.ipynb           simpsons_episodes.csv*
# fulldata-characters.ipynb   simpsons_locations.csv*
# fulldata-locations.ipynb    simpsons_script_lines.csv*
# fulldata-spoken.ipynb       simpstart.ipynb
# merging-outer.ipynb

# %%
df = pd.read_csv('alltogether_outer.csv', index_col=0)
# Out:
# /Users/neil/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
df.head(2)
# Out:
#     episode_id  number                                      raw_text  \
# id
# 1            1       0  (Street: ext. street - establishing - night)
# 2            1       1                       (Car: int. car - night)
#
#     timestamp_in_ms speaking_line  character_id  location_id  \
# id
# 1             8,000         False           nan            1
# 2             8,000         False           nan            2
#
#    raw_character_text raw_location_text spoken_words   ...   number_in_season  \
# id                                                     ...
# 1                 NaN            Street          NaN   ...                  1
# 2                 NaN               Car          NaN   ...                  1
#
#    number_in_series us_viewers_in_millions   views imdb_rating imdb_votes  \
# id
# 1                 1                     27 171,408           8       3734
# 2                 1                     27 171,408           8       3734
#
# ...

# %%
df.fillna(0)
# Out:
#          episode_id  number  \
# id
# 1                 1       0
# 2                 1       1
# 3                 1       2
# 4                 1       3
# 5                 1       4
# 6                 1       5
# 7                 1       6
# 8                 1       7
# 9                 1       8
# 10                1       9
# 11                1      10
# 12                1      11
# 13                1      12
# 14                1      13
# 15                1      14
# 16                1      15
# 17                1      16
# 18                1      17
# 19                1      18
# 20                1      19
# 21                1      20
# 22                1      21
# 23                1      22
# 24                1      23
# 25                1      24
# 26                1      25
# 27                1      26
# 29                1      28
# 28                1      27
# 30                1      29
# ...             ...     ...
# 158,286         568     176
# ...

# %%
i = 2
data = df['raw_character_text'][i]
data
# Out:
# nan

# %%
i = 2
data = df['raw_character_text'][i]
label = df['episode_id'][i]
pd.Series(data,label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-90d2aa00c76e> in <module>()
#       2 data = df['raw_character_text'][i]
#       3 label = df['episode_id'][i]
# ----> 4 pd.Series(data,label)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3257                 value = maybe_cast_to_datetime(value, dtype)
#    3258
# -> 3259             subarr = create_from_value(value, index, dtype)
# ...

# %% [markdown]
# x

# %% [markdown]
# I would like to see how frequent a location occurs throughout the program. Lets first get the total number of episodes and seasons.

# %%
df['season'].nunique()
# Out:
# 26

# %%
df['episode_id'].nunique()
# Out:
# 568

# %%
df.columns
# Out:
# Index(['episode_id', 'number', 'raw_text', 'timestamp_in_ms', 'speaking_line',
#        'character_id', 'location_id', 'raw_character_text',
#        'raw_location_text', 'spoken_words', 'normalized_text', 'name_x',
#        'normalized_name_x', 'title', 'original_air_date', 'production_code',
#        'season', 'number_in_season', 'number_in_series',
#        'us_viewers_in_millions', 'views', 'imdb_rating', 'imdb_votes',
#        'image_url', 'name_y', 'normalized_name_y', 'gender'],
#       dtype='object')

# %%
df['normalized_text']
# Out:
# id
# 1                                                        NaN
# 2                                                        NaN
# 3                                          ooo careful homer
# 4                               theres no time to be careful
# 5                                                  were late
# 6                                                        NaN
# 7                                                        NaN
# 8                                  sorry excuse us pardon me
# 9          hey norman hows it going so you got dragged do...
# 10                                        pardon my galoshes
# 11         wasnt that wonderful and now santas of many la...
# 12                                            oh lisas class
# 13         frohlich weihnachten -- thats german for merry...
# 14         meri kurimasu i am hotseiosha a japanese pries...
# 15         and now presenting lisa simpson as tawanga the...
# ...

# %% [markdown]
# want to see who speaks the most

# %%
df.columns

# %%
df['normalized_text'].nunique()

# %%
spoken = {}

# %%
spoken
# Out:
# {'Homer Simpson': ['theres no time to be careful',
#   'were late',
#   nan,
#   nan,
#   'theres no time to be careful',
#   'were late',
#   'were late'],
#  nan: [nan, nan, nan]}

# %% [markdown]
# Lets create a loop to get all the locations of every episode and dump them into a list.

# %%
for i in range(1,300):
    spoken.setdefault(df['raw_character_text'][i], []).append(df['normalized_text'][i])

# %%
spoken['Homer Simpson'][1]
# Out:
# 'were late'

# %%
#number of doh's per season

# %%
t = pd.Series(spoken,index=spoken.keys())

# %%
df.columns
# Out:
# Index(['episode_id', 'number', 'raw_text', 'timestamp_in_ms', 'speaking_line',
#        'character_id', 'location_id', 'raw_character_text',
#        'raw_location_text', 'spoken_words', 'normalized_text', 'name_x',
#        'normalized_name_x', 'title', 'original_air_date', 'production_code',
#        'season', 'number_in_season', 'number_in_series',
#        'us_viewers_in_millions', 'views', 'imdb_rating', 'imdb_votes',
#        'image_url', 'name_y', 'normalized_name_y', 'gender'],
#       dtype='object')

# %%
ddd = df['spoken_words'].where(df['character_id']==2)

# %%
dd = ddd.dropna( how='all')

# %%
dd.head()
# Out:
# id
# 4                        There's no time to be careful.
# 5                                           We're late.
# 9     Hey, Norman. How's it going? So you got dragge...
# 10                                  Pardon my galoshes.
# 16                          Oh, it's Lisa. That's ours.
# Name: spoken_words, dtype: object

# %%
k = 9
dd[k] = dd[k].split()

# %%
dd.str.split()
# Out:
# id
# 4                                                        NaN
# 5                                                        NaN
# 9                                                        NaN
# 10                                   [Pardon, my, galoshes.]
# 16                         [Oh,, it's, Lisa., That's, ours.]
# 22            [How, many, grades, does, this, school, have?]
# 25         [Marge,, haven't, you, finished, that, stupid,...
# 27                                                  [Marge!]
# 29                  [Marge,, where's, the, extension, cord?]
# 31         [Sorry., I'm, just, a, big, kid, and, I, love,...
# 32                                         [...Every, year.]
# 39                                                [A, what!]
# 42         [Yeah., If, you, want, one,, you'll, have, to,...
# 45                                                 [Y'ello.]
# 47                                            [Who's, this?]
# ...

# %%
dd.head()
# Out:
# id
# 4                 [There's, no, time, to, be, careful.]
# 5                                        [We're, late.]
# 9     [Hey,, Norman., How's, it, going?, So, you, go...
# 10                                  Pardon my galoshes.
# 16                          Oh, it's Lisa. That's ours.
# Name: spoken_words, dtype: object

# %%
dd.to_csv('test.csv')

# %%
dft = pd.DataFrame(spoken)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-4af971d701ba> in <module>()
# ----> 1 dft = pd.DataFrame(spoken)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
# ...

# %%
t['Homer Simpson'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-618ada24761f> in <module>()
# ----> 1 t['Homer Simpson'].value_counts()
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
spoken['Homer Simpson'].append('Test')

# %%
spoken
# Out:
# {'Homer Simpson': ['theres no time to be careful',
#   'were late',
#   nan,
#   nan,
#   'theres no time to be careful',
#   'were late',
#   'were late',
#   'Test',
#   'Test'],
#  nan: [nan, nan, nan]}

# %%
i = 4
#spoken.setdefault(df['raw_character_text'][i], []).append(df['normalized_text'][5])
spoken.setdefault(df['raw_character_text'][i], df['normalized_text'][4])
# Out:
# ['theres no time to be careful',
#  'were late',
#  nan,
#  nan,
#  'theres no time to be careful',
#  'were late',
#  'were late']

# %%
spoken[df['raw_character_text'][4]].append("random")

# %%
spoken[df['raw_character_text'][4]]
# Out:
# ['theres no time to be careful',
#  'were late',
#  'hey norman hows it going so you got dragged down here too heh heh how ya doing fred excuse me fred',
#  'pardon my galoshes',
#  'oh its lisa thats ours',
#  'how many grades does this school have',
#  'marge havent you finished that stupid letter yet',
#  'marge',
#  'marge wheres the extension cord',
#  'sorry im just a big kid and i love christmas so much',
#  'every year',
#  'a what',
#  'yeah if you want one youll have to pay for it out of your own allowance',
#  'yello',
#  'whos this',
#  'this is her sister isnt it',
#  'who shall i say is calling',
#  'its your sister',
#  'okay kids prepare to be dazzled marge turn on the juice',
#  'what do you think kids',
#  'what is it flanders',
#  'its too bright that flanders what a big show-off',
#  'spill it marge where have you been hiding the christmas money',
#  'oh big jar this year',
#  'mm-hmm mmm-hmm mmm-hmm',
#  'mmm-hmm mmm-hmm',
#  'oh thank god for the big jar',
# ...

# %%
df['location_id'].count()
# Out:
# 157865

# %%
i = "name"
i = []
i.insert(0,"dfdf")
i.insert(0,"ddd")
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-fe87b90118e2> in <module>()
#       3 i.insert(0,"dfdf")
#       4 i.insert(0,"ddd")
# ----> 5 name
#
# NameError: name 'name' is not defined

# %%
spoken = dict.fromkeys(character_keys,[])

# %%
#spoken['Marge Simpson']
df['raw_character_text'][3]
# Out:
# 'Marge Simpson'

# %%
spoken['Marge Simpson'].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-5e109ae6224f> in <module>()
# ----> 1 spoken['Marge Simpson'].add("hey")
#
# AttributeError: 'list' object has no attribute 'add'

# %%
#spoken[(df['raw_character_text'][3])].extend("to one")
spoken.setdefault(df['raw_character_text'], []).append(df['normalized_text'])

# %%
df['raw_character_text'][3]
df['normalized_text'][3]
# Out:
# 'ooo careful homer'

# %%
character_keys = df['raw_character_text'].unique()

# %%
type(character_keys)
# Out:
# numpy.ndarray

# %%
df_test = pd.DataFrame(whospeaks)

# %%
df.columns
# Out:
# Index(['episode_id', 'number', 'raw_text', 'timestamp_in_ms', 'speaking_line',
#        'character_id', 'location_id', 'raw_character_text',
#        'raw_location_text', 'spoken_words', 'normalized_text', 'name_x',
#        'normalized_name_x', 'title', 'original_air_date', 'production_code',
#        'season', 'number_in_season', 'number_in_series',
#        'us_viewers_in_millions', 'views', 'imdb_rating', 'imdb_votes',
#        'image_url', 'name_y', 'normalized_name_y', 'gender'],
#       dtype='object')

# %%
df_test[0].value_counts()
# Out:
# no                                                                                                                  105
# yes                                                                                                                  80
# what                                                                                                                 47
# yeah                                                                                                                 43
# hey                                                                                                                  37
# okay                                                                                                                 37
# ow                                                                                                                   35
# hello                                                                                                                33
# ...

# %% [markdown]
# It doesn't look right that 55 out of 600 episodes would not have the "simpson home". So lets take a look at those episodes.

# %%
df['title'][(df['normalized_name_x'] != "simpson home")].unique()
# Out:
# array(['Simpsons Roasting on an Open Fire', 'Bart the Genius',
#        "Homer's Odyssey", "There's No Disgrace Like Home",
#        'Bart the General', 'Moaning Lisa', 'The Call of the Simpsons',
#        'The Telltale Head', 'Life on the Fast Lane', "Homer's Night Out",
#        'The Crepes of Wrath', 'Krusty Gets Busted',
#        'Some Enchanted Evening', 'Bart Gets an "F"',
#        'Simpson and Delilah', 'Treehouse of Horror',
#        'Two Cars in Every Garage and Three Eyes on Every Fish',
#        "Dancin' Homer", 'Dead Putting Society', 'Bart vs. Thanksgiving',
#        'Bart the Daredevil', 'Itchy & Scratchy & Marge',
#        'Bart Gets Hit by a Car',
#        'One Fish, Two Fish, Blowfish, Blue Fish', 'The Way We Was',
#        'Homer vs. Lisa and the 8th Commandment', 'Principal Charming',
#        'Oh Brother, Where Art Thou?', 'Bart\'s Dog Gets an "F"',
#        'Old Money', 'Brush with Greatness', "Lisa's Substitute",
# ...

# %%
x = df['episode_id'].nunique()

# %%
type(x)
# Out:
# int

# %%
df['season'].nunique()
# Out:
# 26

# %%
df['episode_id'].nunique()
# Out:
# 568

# %%
df.columns
# Out:
# Index(['episode_id', 'number', 'raw_text', 'timestamp_in_ms', 'speaking_line',
#        'character_id', 'location_id', 'raw_character_text',
#        'raw_location_text', 'spoken_words', 'normalized_text', 'name_x',
#        'normalized_name_x', 'title', 'original_air_date', 'production_code',
#        'season', 'number_in_season', 'number_in_series',
#        'us_viewers_in_millions', 'views', 'imdb_rating', 'imdb_votes',
#        'image_url', 'name_y', 'normalized_name_y', 'gender'],
#       dtype='object')

# %%
df['normalized_name_x'].where(df['season'] <11)
# Out:
# id
# 1                                 street
# 2                                    car
# 3                                    car
# 4                                    car
# 5                                    car
# 6          springfield elementary school
# 7                             auditorium
# 8                             auditorium
# 9                             auditorium
# 10                            auditorium
# 11                            auditorium
# 12                            auditorium
# 13                            auditorium
# 14                            auditorium
# 15                            auditorium
# 16                            auditorium
# 17                            auditorium
# 18                            auditorium
# 19                            auditorium
# 20                            auditorium
# 21                            auditorium
# 22                            auditorium
# 23                          simpson home
# ...

# %%
tempgood = []
for i in range(1,good['episode_id'].nunique()):
    locs = good['normalized_name_x'].where(good['episode_id']==i).unique()
    tempgood.extend(locs)
    #print(i)

good_test = pd.DataFrame(tempgood)

'''
remove
------
simpson home
springfield
springfield street
street
'''
good_test[0].value_counts()
# Out:
# simpson home                                                    221
# moe tavern                                                       94
# springfield elementary school                                    93
# springfield nuclear power plant                                  85
# street                                                           75
# simpson car                                                      60
# kwik-e-mart                                                      56
# simpson living room                                              42
# springfield                                                      41
# simpson kitchen                                                  35
# springfield retirement castle                                    34
# flanders home                                                    32
# first church of springfield                                      29
# springfield street                                               28
# ...

# %%
tempbad = []
for i in range(1,bad['episode_id'].nunique()):
    locs = bad['normalized_name_x'].where(bad['episode_id']==i).unique()
    tempbad.extend(locs)
    #print(i)

bad_test = pd.DataFrame(tempbad)

'''
remove
------
springfield
springfield street
street
car
evergreen terrace
'''


bad_test[0].value_counts()
# Out:
# simpson home                       139
# springfield elementary school       64
# moe tavern                          63
# springfield                         55
# springfield street                  47
# springfield nuclear power plant     42
# street                              38
# simpson living room                 35
# simpson car                         33
# kwik-e-mart                         30
# flanders home                       27
# car                                 27
# evergreen terrace                   24
# first church of springfield         24
# springfield town hall               22
# lisa bedroom                        18
# springfield police station          18
# simpson backyard                    16
# beach                               16
# springfield streets                 15
# highway                             15
# living room                         15
# springfield retirement castle       15
# springfield town square             14
# ...

# %%
#bad_test[0].str.contains("springfield")

# %%
bad_test[0].value_counts()[bad_test[0].value_counts()<2]
# Out:
# fork in road                        1
# reality channel studios             1
# field outside fortress              1
# side of the road                    1
# dude ranch                          1
# homer and marge bungalow            1
# capital city street                 1
# springfield square garden           1
# springfield trade center            1
# selma hospital room                 1
# lovejoy van                         1
# dirt road                           1
# crappy apartment complex            1
# prof frink booth                    1
# children hospital                   1
# canadian vfw-style building         1
# henhouse                            1
# house next door                     1
# st jerome                           1
# steam room                          1
# the singing sirloin                 1
# beijing street                      1
# graduation stage                    1
# taste of springfield festival       1
# camp david                          1
# ...

# %% [markdown]
# #

# %% [markdown]
# So I thought looking at the data that "Iowa Non-International Airport" was wrong. I just don't know my simpsons we well as I used to :(

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
good = df.drop(df[df['season'] > 10].index)

# %%
bad = df.drop(df[df['season'] <= 10].index)

# %%
good.head()
# Out:
#     episode_id  number                                       raw_text  \
# id
# 1            1       0   (Street: ext. street - establishing - night)
# 2            1       1                        (Car: int. car - night)
# 3            1       2            Marge Simpson: Ooo, careful, Homer.
# 4            1       3  Homer Simpson: There's no time to be careful.
# 5            1       4                     Homer Simpson: We're late.
#
#     timestamp_in_ms speaking_line  character_id  location_id  \
# id
# 1             8,000         False           nan            1
# 2             8,000         False           nan            2
# 3             8,000          True             1            2
# 4            10,000          True             2            2
# 5            10,000          True             2            2
#
#    raw_character_text raw_location_text                    spoken_words  \
# id
# 1                 NaN            Street                             NaN
# ...

# %%
bad_test[0].value_counts()[bad_test[0].value_counts()==1].count()
# Out:
# 1232

# %%
good_test[0].value_counts()[good_test[0].value_counts()==1].count()
# Out:
# 1557

# %%
bad_test[0].value_counts()[bad_test[0].value_counts()==1].count()/(good_test[0].value_counts()[good_test[0].value_counts()==1].count() + bad_test[0].value_counts()[bad_test[0].value_counts()==1].count())
# Out:
# 0.44173538902832554

# %%
good_test[0].value_counts()[good_test[0].value_counts()==1].count()/(good_test[0].value_counts()[good_test[0].value_counts()==1].count() + bad_test[0].value_counts()[bad_test[0].value_counts()==1].count())
# Out:
# 0.5582646109716745

# %% [markdown]
# number of single locations

# %%
bad_test[0].value_counts()[bad_test[0].value_counts()<2]
# Out:
# fork in road                        1
# reality channel studios             1
# field outside fortress              1
# side of the road                    1
# dude ranch                          1
# homer and marge bungalow            1
# capital city street                 1
# springfield square garden           1
# springfield trade center            1
# selma hospital room                 1
# lovejoy van                         1
# dirt road                           1
# crappy apartment complex            1
# prof frink booth                    1
# children hospital                   1
# canadian vfw-style building         1
# henhouse                            1
# house next door                     1
# st jerome                           1
# steam room                          1
# the singing sirloin                 1
# beijing street                      1
# graduation stage                    1
# taste of springfield festival       1
# camp david                          1
# ...

# %%
good_test[0].value_counts()[good_test[0].value_counts()<2].count()
# Out:
# 1557

# %%
good_test[0].value_counts()[good_test[0].value_counts()<2]
# Out:
# psychiatric center                                              1
# downstairs hallway                                              1
# homer boyhood home                                              1
# spooky victorian house                                          1
# airline headquarters                                            1
# mc mahon and tate advertising agency                            1
# testing course                                                  1
# huge bookstore                                                  1
# flanders front yard                                             1
# dermatology clinic                                              1
# egyptian exhibit room                                           1
# airplane runway                                                 1
# beer hall of the presidents                                     1
# far side of parking lot                                         1
# ...

# %%
bad_test[0].value_counts()[bad_test[0].value_counts()>20]
# Out:
# simpson home                       139
# springfield elementary school       64
# moe tavern                          63
# springfield                         55
# springfield street                  47
# springfield nuclear power plant     42
# street                              38
# simpson living room                 35
# simpson car                         33
# kwik-e-mart                         30
# flanders home                       27
# car                                 27
# evergreen terrace                   24
# first church of springfield         24
# springfield town hall               22
# Name: 0, dtype: int64

# %%
good_test[0].value_counts()[good_test[0].value_counts()>20]
# Out:
# simpson home                       221
# moe tavern                          94
# springfield elementary school       93
# springfield nuclear power plant     85
# street                              75
# simpson car                         60
# kwik-e-mart                         56
# simpson living room                 42
# springfield                         41
# simpson kitchen                     35
# springfield retirement castle       34
# flanders home                       32
# first church of springfield         29
# springfield street                  28
# homer car                           26
# bart bedroom                        26
# burns office                        26
# kitchen                             25
# lisa bedroom                        24
# school bus                          23
# springfield mall                    23
# springfield town hall               23
# car                                 22
# springfield police station          21
# ...

# %%
good_test[0].value_counts().count()
# Out:
# 1940

# %%
bad_test[0].value_counts().count()
# Out:
# 1532

# %%
df.columns
# Out:
# Index(['episode_id', 'number', 'raw_text', 'timestamp_in_ms', 'speaking_line',
#        'character_id', 'location_id', 'raw_character_text',
#        'raw_location_text', 'spoken_words', 'normalized_text', 'name_x',
#        'normalized_name_x', 'title', 'original_air_date', 'production_code',
#        'season', 'number_in_season', 'number_in_series',
#        'us_viewers_in_millions', 'views', 'imdb_rating', 'imdb_votes',
#        'image_url', 'name_y', 'normalized_name_y', 'gender'],
#       dtype='object')

# %%
df['raw_character_text'].str.contains('Homer Simpson').dropna().values
# Out:
# array([False, True, True, ..., True, False, False], dtype=object)

# %%
words.columns
# Out:
# Index(['id', 'episode_id', 'number', 'raw_text', 'timestamp_in_ms',
#        'speaking_line', 'character_id', 'location_id', 'raw_character_text',
#        'raw_location_text', 'spoken_words', 'normalized_text', 'word_count',
#        'name_x', 'normalized_name_x', 'title', 'original_air_date',
#        'production_code', 'season', 'number_in_season', 'number_in_series',
#        'us_viewers_in_millions', 'views', 'imdb_rating', 'imdb_votes',
#        'image_url', 'video_url', 'name_y', 'normalized_name_y', 'gender'],
#       dtype='object')

# %%
words = pd.read_csv('alltogether_outer_words.csv', index_col=0)
# Out:
# /Users/neil/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
words['word_count'].where(words['raw_character_text']=='Homer Simpson')
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
#          ...
# 159341    NaN
# 159342    NaN
# 159343    NaN
# 159344    NaN
# 159345    NaN
# 159346    NaN
# 159347    NaN
# 159348    NaN
# 159349    NaN
# 159350    NaN
# 159351    NaN
# 159352    NaN
# 159353    NaN
# 159354    NaN
# 159355    NaN
# 159356    NaN
# 159357    NaN
# 159358    NaN
# 159359    NaN
# 159360    NaN
# 159361    NaN
# 159362    NaN
# 159363    NaN
# 159364    NaN
# 159365    NaN
# 159366    NaN
# 159367    NaN
# 159368    NaN
# 159369    NaN
# 159370    NaN
# ...
