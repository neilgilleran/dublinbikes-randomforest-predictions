# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("2014-2018_Station34_features.csv")

# %%
df.head()
# Out:
#              timestamp  bikes  spaces  total_docks  bike_lag  bike_lag2  \
# 0  2014-06-28 00:00:01     30       0            0         0          0
# 1  2014-06-28 00:10:01     30       0            0        30          0
# 2  2014-06-28 00:20:02     30       0            0        30         30
# 3  2014-06-28 00:30:02     30       0            0        30         30
# 4  2014-06-28 00:40:02     29       1            0        30         30
#
#    bike_lag3  bike_lag4  bike_pull  bike_pull2  bike_pull3  bike_pull4  \
# 0          0          0         30          30          30          29
# 1          0          0         30          30          29          30
# 2          0          0         30          29          30          30
# 3         30          0         29          30          30          30
# 4         30         30         30          30          30          30
#
#    deposit  hour  day_of_week  minute  month  weekend      time
# ...

# %%
df = df.drop('bike_lag',axis=1)
df = df.drop('bike_lag2',axis=1)
df = df.drop('bike_lag3',axis=1)
df = df.drop('bike_lag4',axis=1)
df.head(2)
# Out:
#              timestamp  bikes  spaces  total_docks  bike_pull  bike_pull2  \
# 0  2014-06-28 00:00:01     30       0            0         30          30
# 1  2014-06-28 00:10:01     30       0            0         30          30
#
#    bike_pull3  bike_pull4  deposit  hour  day_of_week  minute  month  weekend  \
# 0          30          29        0     0            5       0      6        1
# 1          29          30        0     0            5      10      6        1
#
#        time
# 0  00:00:01
# 1  00:10:01

# %%
df = df.drop('bike_pull',axis=1)
df = df.drop('bike_pull2',axis=1)
df = df.drop('bike_pull3',axis=1)
df = df.drop('bike_pull4',axis=1)

df.head(2)
# Out:
#              timestamp  bikes  spaces  total_docks  deposit  hour  \
# 0  2014-06-28 00:00:01     30       0            0        0     0
# 1  2014-06-28 00:10:01     30       0            0        0     0
#
#    day_of_week  minute  month  weekend      time
# 0            5       0      6        1  00:00:01
# 1            5      10      6        1  00:10:01

# %%
df['time'] < '05:30:00' &  (df['time'] > '00:30:00')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     900         try:
# --> 901             result = op(x, y)
#     902         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#     132                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 133                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     134                                    names('rand_'), op('&')),
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
df['time'] < '05:30:00' | (df['time'] > '00:30:00')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     900         try:
# --> 901             result = op(x, y)
#     902         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#     134                                    names('rand_'), op('&')),
# --> 135                  ror_=bool_method(lambda x, y: operator.or_(y, x),
#     136                                   names('ror_'), op('|')),
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
x = df[df['time'] > '05:30:00']

# %%
df3 = df[(df['time'] > '05:30:00') | (df['time'] < '00:30:00')]

# %%
df3 = df3[df3['weekend']==0]

# %%
df3.to_csv('Station34-mon-fri-0530to0030.csv')

# %%
 early = df[(df['time'] > '05:30:00') & (df['hour'] < 6)]

# %%
dfPivot_means = pd.pivot_table(early, values = "bikes", aggfunc={'bikes': np.mean},
                             columns = "", index = "hour")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-927291487dd7> in <module>()
# ----> 1 dfPivot_means = pd.pivot_table(early, values = "bikes", aggfunc={'bikes': np.mean},
#       2                              columns = "", index = "hour")
#
# NameError: name 'np' is not defined
